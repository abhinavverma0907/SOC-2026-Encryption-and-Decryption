# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavverma0907/SOC-2026-Encryption-and-Decryption/blob/main/Week_0/Assignment_1/Q1_Finding_the_Killer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q1 Finding the Killer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

people = pd.read_csv('/content/drive/MyDrive/SOC-2026/Assignment-1/Q1/unique_people_dataset_2000.csv')
teachers   = pd.read_csv('/content/drive/MyDrive/SOC-2026/Assignment-1/Q1/all_teacher.csv')

people.head()
# Out:
#              name  age  height  weight occupation    location
# 0   Jeffrey Mason   59   173.0    97.1    Teacher  city_north
# 1     Gina Deleon   69   149.8    97.2   Mechanic   city_west
# 2  Victoria Davis   54   171.2    60.0      Pilot   city_west
# 3   Angela Torres   46   162.7    72.7  Scientist  city_north
# 4       Tara Pace   58   197.4    51.1    Analyst   city_east

# %%
teachers.head()
# Out:
#               name  age  height  weight occupation    location  Joining year
# 0    Jeffrey Mason   59   173.0    97.1    Teacher  city_north          2005
# 1  Nicholas Rivera   37   147.7    98.4    Teacher   city_east          2005
# 2   John Armstrong   38   169.0    62.0    Teacher  city_north          2018
# 3       John Yates   27   160.8    92.8    Teacher   city_west          2001
# 4     Joseph Colon   42   198.5    54.2    Teacher   city_west          2018

# %% [markdown]
# ##Suspect filtering on people

# %%
suspects = people[
    (people['age'] >= 30) & (people['age'] <= 45) &
    (people['height'] >= 160) & (people['height'] <= 190) &
    (people['weight'] >= 50) & (people['weight'] <= 100) &
    (people['location'].isin(['city_south','city_east']))
]
print('Number of suspects:', suspects.shape[0])
suspects
# Out:
# Number of suspects: 113
#                    name  age  height  weight  occupation    location
# 8        Robert Collins   32   180.7    71.5      Writer   city_east
# 12      Patricia Walker   34   170.2    75.8   Architect  city_south
# 102         Kevin Green   30   162.9    75.6  Consultant   city_east
# 123   Brittany Gonzalez   44   183.1    68.9    Mechanic  city_south
# 124         Lisa Chavez   32   183.4    59.4     Analyst  city_south
# ...                 ...  ...     ...     ...         ...         ...
# 1952     Carol Williams   41   169.7    70.1       Nurse  city_south
# 1963          Kerry Day   45   169.3    83.0    Mechanic  city_south
# 1978      Jhon Williams   44   169.4    85.9     Teacher  city_south
# 1989         Lori Clark   44   180.2    51.9     Analyst  city_south
# 1999    Devon Blanchard   33   181.5    83.0   Scientist   city_east
#
# [113 rows x 6 columns]

# %% [markdown]
# ##Suspect filtering on teachers

# %%
suspects = teachers[
    (teachers['age'] >= 30) & (teachers['age'] <= 45) &
    (teachers['height'] >= 160) & (teachers['height'] <= 190) &
    (teachers['weight'] >= 50) & (teachers['weight'] <= 100) &
    (teachers['location'].isin(['city_south','city_east']))
]
print('Number of suspects:', suspects.shape[0])
suspects
# Out:
# Number of suspects: 2
#              name  age  height  weight occupation    location  Joining year
# 57    Laura Davis   32   164.5    95.7    Teacher   city_east          2024
# 82  Jhon Williams   44   169.4    85.9    Teacher  city_south          2010

# %% [markdown]
# ##"close friend since long"-logic

# %% [markdown]
# ## Conclusion
#
# **Killer: Jhon Williams** (Teacher, age 44, city_south, joined 2010)
#
# ### Reasoning
# 1. **Physical description** suspects to age 30–45, height 160–190 cm, weight 50–100 kg.
# 2. **Wife's hint** pointed to colleagues → filtered to teachers table only.
# 3. **Family says home at 10 PM** ruled out city_north and city_west
#    (forest closed after 8 PM, long route too slow to reach crime scene by 10:45)
# 4. Only **city_east and city_south** were feasible → 2 teacher matched.
# 5. **Joining year 2010** matches the victim's "more than a decade" of teaching —
#    they likely started together, supporting "close friend since long"
#
# ### Motive
# Jhon Williams and the victim joined the school together in 2010, both fresh and ambitious. Over the years they grew close — sharing classes, lunch breaks, and the quiet bridge by the pond in city east, where they'd unwind with a drink after long weeks. It was their spot.
# But last month, when the post of senior teacher opened up, the principal chose the victim over Jhon. Outwardly Jhon smiled and congratulated him. Inwardly something had snapped — fourteen years of effort overlooked in a single decision.
# On Monday night they met at the bridge as usual. The drinks flowed, and the victim, half-joking, brought up the promotion — perhaps even hinted that Jhon "wasn't quite ready yet." A knife lay on the rocks beside them, brought out earlier to slice fruit for the snacks. In the heat of the moment, fueled by alcohol and years of bottled resentment, Jhon picked it up.
# By the time he realized what he had done, his closest friend lay still beside the pond. He ran.
